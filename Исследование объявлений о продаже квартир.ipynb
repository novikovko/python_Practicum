# %% [markdown]
# <div  style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
#
# **Кирилл, привет!**
#
# Меня зовут Василий Митров и я буду проверять твой проект. Предлагаю общаться на «ты». Если это неприемлемо, то дай мне знать и мы перейдем на «вы».
#
# Для удобства я оставлю комментарии в отдельных ячейках Markdown с заголовком «Комментарий ревьюера». Пожалуйста, не перемещай, не изменяй и не удаляй их - так наше общение будет более продуктивным. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# ✍ Так выделены самые важные замечания. Без их отработки проект не будет принят. При проверке я обращаю внимание не только на код, но и на интерпретацию и анализ результатов, а также соответствие данных техническому заданию.
# </div>
#
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 📝 Так выделены небольшие замечания или рекомендации. Постарайся, пожалуйста, учесть эти комментарии в этом проекте или в будущих проектах.
# </div>
#
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера</b>
#
# 👍 Так выделены все остальные комментарии, включая рекомендации, позитивные моменты или какие-то рассуждения и пояснения.
# </div>
#
# **Важные дополнения:**
#
# * <u>Идеально, когда проект структурирован. Где названия разделов и подразделов будут записаны в ячейках [Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/?).</u>
#
#
# * <u>Проверь проект на работоспособность перед отправкой на проверку. Сделать это можно так: `Kernel -> Restart And Run All -> Restart And Run All Cells` предварительно сохранив проект нажав на дискету в левом верхнем углу. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании. Помни, ревьюеры не вносят изменения в код, даже если это путь к датасету или ячейка в неверном формате (code/mardown).</u>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Например, вот так. Также, если есть какие-то вопросы, или что-то осталось непонятным по ревью - спрашивай в таких блоках и я постараюсь дать ответ.
# </div>
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Правильно делаешь, что не убираешь описание задачи. Это поможет быстро вспомнить, о чем проект, если ты к нему вернешься спустя какое-то время.
#
# Данный блок можно расширить при помощи плана работы и описания данных. Посмотреть подробнее про вступительный блок можно в разделе "Полезные инструкции в учебе" блока "Оформление проекта".
#
# Также советую тебе посмотреть на <a href="https://www.kaggle.com/notebooks/">работы</a>  аналитиков, чтобы оценить, как более опытные коллеги оформляют и проводят исследования.
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# <B>Импортируем библиотеки.</B>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Правильно, что весь импорт ты проводишь в первой ячейке работы. Так твой коллега, запускающий работу, будет в курсе используемых в ней библиотек и сможет при необходимости быстро настроить окружение.
# </div>

# %% [markdown]
# <B>Прочитаем файл и запишем его в переменную data.</B>

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep = '\t')

# %% [markdown]
# <B>Выведем информацию о датафрейме.</B>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <b>Выведем первые 10 строк датафрейма.</b>

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# <b>Построим общую гистограмму по всем числовым столбцов датафрейма.</b>

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Предупреждения перед графиками можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку matplotlib.pyplot as plt
# 2. В конец кода добавить `;`
# </div>

# %% [markdown]
# <b>Посмотрим статистическую сводку по каждому числовому столбцу датафрейма. </b>

# %%
data.describe().T
# Out:
#                        count          mean           std      min         25%  \
# total_images         23699.0  9.858475e+00  5.682529e+00      0.0        6.00
# last_price           23699.0  6.541549e+06  1.088701e+07  12190.0  3400000.00
# total_area           23699.0  6.034865e+01  3.565408e+01     12.0       40.00
# rooms                23699.0  2.070636e+00  1.078405e+00      0.0        1.00
# ceiling_height       14504.0  2.771499e+00  1.261056e+00      1.0        2.52
# floors_total         23613.0  1.067382e+01  6.597173e+00      1.0        5.00
# living_area          21796.0  3.445785e+01  2.203045e+01      2.0       18.60
# floor                23699.0  5.892358e+00  4.885249e+00      1.0        2.00
# kitchen_area         21421.0  1.056981e+01  5.905438e+00      1.3        7.00
# balcony              12180.0  1.150082e+00  1.071300e+00      0.0        0.00
# airports_nearest     18157.0  2.879367e+04  1.263088e+04      0.0    18585.00
# ...

# %% [markdown]
# <b>Посмотрим количество пропусков в столбцах.</b>

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Также, помимо абсолютных значений мы можем посмотреть долю пропусков, и на основании этого принять решение о удалении, замене либо игнорировании пропусков, например: `pd.DataFrame(round(df.isna().mean()*100,1)).style.background_gradient('coolwarm')`
#
#
# </div>

# %% [markdown]
# <b>Из анализа полученных данных можно сделать следующие выводы: </b>
# 1. всего в датафрейме 23699 строк и 22 столбца. Причем 17 столбцов являются числовыми.
# 2. Столбцы total_images, last_price, total_area,first_day_exposition, rooms, floor, studio, open_plan не содержат пропусков.
# 3. Столбцы parks_around3000, ponds_around3000, cityCenters_nearest не приведены к змеиному регистру.
# 4. Столбец is_apartment содержит большое количество пропусков, однако это значит, что данный объект не является аппартаментами. Заменим их на "False".
# 5. Столбцы floors_total, locality_name содержат незначительное количество пропусков (<2%), однако на дальнейший анализ они не повлияют.
# 6. Столбец balkony содержит большое количество пропусков. Но пропуски в этом столбце мы принимаем за 0-ое количество балконов в квартире.
# 7. Столбец ceiling_height тоже содержит ошибки в данных. Так как максимальная 100м высота потолка не отражают действительные значения.
# 8. Столбец living_area содержит ошибки. Минимальное метраж квартиры 2м². Такие данные мы будем удалять.
# 9. Аналогичная ситуация с столбцом kitchen_area. Минимальный метраж кухни 1.3м². Такие данные тоже будем удалять.
# 10. Столбец first_day_exposition необходимо привести к типу datetime.

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Хорошая вводная часть.
#
# Рекомендую создать универсальную функцию, которая будет принимать на вход датафрейм, а на выходе она будет выводить всего нужные характеристики, например, head, describe, info, дубликаты и т.п.
# </div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# <b>Стобцы parks_around3000, ponds_around3000, cityCenters_nearest приведем к змеиному регистру. </b>

# %%
data = data.rename(columns={'cityCenters_nearest': 'city_centers_nearest', 
                            'parks_around3000': 'parks_around_3000', 
                            'ponds_around3000': 'ponds_around_3000'})

# %% [markdown]
# <b>Проверим единообразность стиля столбцов. Посмотрим первые 5 строк.</b>

# %%
pd.options.display.max_columns = None # зададим опцию, чтобы посмотреть все столбцы
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <b>Перейдем к обработке пропусков и аномальных значений. Еще раз посмотрим на статистику пропущенных значений по столбцам. </b>

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <b>В столбце ceiling_height 9195 пропусков (39% от всех данных). Это информация о высоте потолков, и мы можем заменить пропуски медианным значением.</b>

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Верно. Потолки это довольно стандартизированная величина, поэтому пропуски можно безболезненно заменить их медианой.
# </div>

# %% [markdown]
# <b>Проверим, остались ли пропуски.</b>

# %%
data['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# <b>Удалим строки с аномальными значениями высоты потолков.</b>

# %% [markdown]
# <b>Рассмотрим распределение ceiling_height:</b>

# %%
data['ceiling_height'].sort_values().plot(y = 'ceiling_height', kind = 'hist', bins = 15, range=(2,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# <b>Выведем статистику по ceiling_height.</b>

# %%
data['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.724358
# std          0.988298
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# <b>Отбросим из выборки те строки, у которых высота потолков больше среднего + 3 std. </b>

# %%
del_count = 0 # введем счетчик удаленных строк
del_count += data[data['ceiling_height']> 5.69]['ceiling_height'].count()
data = data.loc[data['ceiling_height']<=5.69]

# %% [markdown]
# <b>Пропусков в столбцах floors_total, locality_name очень мало, однако для анализа эти данные не повлияют на исследование. Пока что оставим их. Столбец living_area содержит 1903 пропуска. Данные в этом столбце заменим медианой следующим образом:
# для квартиры с каждым количеством комнат посчитаем какая медианная доля площади - жилая. Заполним медианой пропуски.</b>

# %%
for i in range(0, data['rooms'].max()):
    ratio = (data[data['rooms'] == i]['living_area'] / data[data['rooms'] == i]['total_area']).median()
    data['living_area'] = data['living_area'].fillna(value = data['total_area'] * ratio)

# %% [markdown]
# <b>Проверим, есть ли случаи, когда жилая площадь больше общей.</b>

# %%
data[data['living_area'] > data['total_area']]['rooms'].count()
# Out:
# 0

# %% [markdown]
# <b>Посмотрим статистику по столбцу living_area.</b>

# %%
data['living_area'].describe()
# Out:
# count    23668.000000
# mean        35.195835
# std         23.022861
# min          2.000000
# 25%         19.000000
# 50%         30.400000
# 75%         42.900000
# max        435.172414
# Name: living_area, dtype: float64

# %% [markdown]
# <b>Уберем из выборки квартиры с жилой площадью менее чем 10м².</b>

# %%
del_count+=data[data['living_area']<10].count()
data = data.loc[data['living_area']>=10]

# %% [markdown]
# <b>Пропуски в столбце is_apartment можно заменить на логическое False, а пропуски в balcony можно заменить на 0.</b>

# %%
data['is_apartment'] = data['is_apartment'].fillna(value=False)
data['balcony'] = data['balcony'].fillna(value=0)

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Все верно, либо это апартаменты, либо нет. Булев тип подходит лучше всего.
# </div>

# %% [markdown]
# <b>По аналогии с жилой площадью заполним пропуски в столбце kitchen_area.</b>

# %%
for i in range(0, data['rooms'].max()):
    ratio = (data[data['rooms'] == i]['kitchen_area'] / data[data['rooms'] == i]['total_area']).median()
    data['kitchen_area'] = data['kitchen_area'].fillna(value = data['total_area'] * ratio)
# Out:
# /opt/conda/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %% [markdown]
# <b>Выведем статистику по столбцу kitchen_area.</b>

# %%
data['kitchen_area'].describe()
# Out:
# count    23640.000000
# mean        10.897190
# std          6.509095
# min          1.300000
# 25%          7.100000
# 50%          9.463961
# 75%         12.000000
# max        123.873833
# Name: kitchen_area, dtype: float64

# %% [markdown]
# <b>Удалим из выборки квартиры, метраж кухни которых меньше 4м².</b>

# %%
del_count+=data[data['kitchen_area']<4].count()
data = data.loc[data['kitchen_area']>=4]

# %% [markdown]
# <b>Пропуски в столбце floors_total удалим.</b>

# %%
del_count+=data['floors_total'].isna().sum()
data = data.dropna(subset=['floors_total'])

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Верно, доля пропусков здесь менее 5% и для экономии времени их можно удалить.
# </div>

# %% [markdown]
# <b>Теперь приобразуем типы данных.</b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23520 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23520 non-null  int64
#  1   last_price            23520 non-null  float64
#  2   total_area            23520 non-null  float64
#  3   first_day_exposition  23520 non-null  object
#  4   rooms                 23520 non-null  int64
#  5   ceiling_height        23520 non-null  float64
#  6   floors_total          23520 non-null  float64
#  7   living_area           23520 non-null  float64
#  8   floor                 23520 non-null  int64
#  9   is_apartment          23520 non-null  bool
#  10  studio                23520 non-null  bool
#  11  open_plan             23520 non-null  bool
#  12  kitchen_area          23520 non-null  float64
#  13  balcony               23520 non-null  float64
#  14  locality_name         23472 non-null  object
# ...

# %% [markdown]
# <b>Преобразуем столбцы last_price и balcony к типу int, так как последняя цена выражена в рублях (копейки нам не нужны), а количество балконов может быть выражено только целочисленно. </b>

# %%
data['last_price'] = data ['last_price'].astype('int')
data['balcony'] = data['balcony'].astype('int')

# %% [markdown]
# <b>Столбец first_day_exposition приведем к типу datetime, время отбросим, так как данные содержат тип дата и время, но мы рассматриваем большие таймфреймы и время нам не дает полезной информации.</b>

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 При чтении файла можно указать параметр `parse_dates: parse_dates=['date']`. Тогда пандас автоматически переведет список столбцов в даты. Пример можно посмотреть [здесь](https://newtechaudit.ru/gruzi-daty-krasivo/).
# </div>

# %% [markdown]
# <b>Столбец is_apartment приведем к булевому типу, так как столбец содержит информацию Да/Нет. </b>

# %%
data['is_apartment'] = data['is_apartment'].astype('bool')

# %% [markdown]
# <b>Столбец floor_total приведем к целочисленному типу</b>

# %%
data['floors_total'] = data['floors_total'].astype('int')

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Привел общее количество этажей к целочисленному типу данных.
# </div>

# %% [markdown]
# <b>Проверим получившиеся типы данных. </b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23520 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23520 non-null  int64
#  1   last_price            23520 non-null  int64
#  2   total_area            23520 non-null  float64
#  3   first_day_exposition  23520 non-null  datetime64[ns]
#  4   rooms                 23520 non-null  int64
#  5   ceiling_height        23520 non-null  float64
#  6   floors_total          23520 non-null  int64
#  7   living_area           23520 non-null  float64
#  8   floor                 23520 non-null  int64
#  9   is_apartment          23520 non-null  bool
#  10  studio                23520 non-null  bool
#  11  open_plan             23520 non-null  bool
#  12  kitchen_area          23520 non-null  float64
#  13  balcony               23520 non-null  int64
#  14  locality_name         23472 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Обрати внимание на тип данных в floors_total, вряд ли бывает 2,5 этажа.
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
#
# </div>

# %% [markdown]
# <b>Теперь проверим наличие явных и неявных дубликатов.</b>

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <b>Явных дубликатов не обнаружено. Очень хороший знак.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍
# Молодец, что не забываешь про явные дубликаты.
# </div>

# %% [markdown]
# <b>Проверим наличие неявных дубликатов в столбце locality_name. Отсортируем и выведем уникальные названия населенных пунктов.</b>

# %%
data['locality_name'].sort_values().unique()
# Out:
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалёво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'городской посёлок Будогощь', 'городской посёлок Виллози',
#        'городской посёлок Лесогорский', 'городской посёлок Мга',
#        'городской посёлок Назия', 'городской посёлок Новоселье',
#        'городской посёлок Павлово', 'городской посёлок Рощино',
# ...

# %% [markdown]
# <b>Заменим "поселок" на "посёлок" в названиях населенных пунктов, а также приведем к единому виду неявные дубликаты. Удалим строки без названия населенного пункта.</b>

# %%
data = data.replace({'locality_name':{'Никольское': 'село Никольское', 'городской посёлок Советский': 'посёлок городского типа Советский', 'городской посёлок Большая Ижора': 'посёлок городского типа Большая Ижора', 'городской посёлок Лесогорский': 'посёлок городского типа Лесогорский', 'посёлок Рябово': 'посёлок городского типа Рябово', 'городской посёлок Мга': 'посёлок городского типа Мга', 'городской посёлок Павлово': 'посёлок городского типа Павлово', 'городской посёлок Назия': 'посёлок городского типа Назия', 'коттеджный посёлок Лесное': 'посёлок Лесное', 'Мурино': 'посёлок Мурино', 'Любань': 'посёлок Любань', 'городской посёлок Рощино': 'посёлок городского типа Рощино', 'деревня Кудрово': 'Кудрово'}})
data['locality_name'] = data['locality_name'].str.replace('поселок','посёлок')
del_count += data['locality_name'].isna().sum()
data = data.dropna(subset=['locality_name'])

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично! Можно еще применить такой подход:
#
#     df = df.apply(lambda x: x.replace({'поселок':'посёлок', 'городской посёлок': 'посёлок', 'посёлок городского типа': 'посёлок', 'коттеджный посёлок': 'посёлок', 'посёлок при железнодорожной станции': 'посёлок станции'}, regex=True))
#
#     len(df.locality_name.unique())
# </div>

# %% [markdown]
# <b>Еще раз посмотрим на информацию о столбцах и первые 10 строк. </b>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23472 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23472 non-null  int64
#  1   last_price            23472 non-null  int64
#  2   total_area            23472 non-null  float64
#  3   first_day_exposition  23472 non-null  datetime64[ns]
#  4   rooms                 23472 non-null  int64
#  5   ceiling_height        23472 non-null  float64
#  6   floors_total          23472 non-null  int64
#  7   living_area           23472 non-null  float64
#  8   floor                 23472 non-null  int64
#  9   is_apartment          23472 non-null  bool
#  10  studio                23472 non-null  bool
#  11  open_plan             23472 non-null  bool
#  12  kitchen_area          23472 non-null  float64
#  13  balcony               23472 non-null  int64
#  14  locality_name         23472 non-null  object
# ...

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# ...

# %% [markdown]
# <b>Итого, в процессе предобработки данных, удалось:</b>
# 1. Привести название столбцов к единому виду.
# 2. Обработать пропуски данных.
# 3. Избавиться от явных и неявных дубликатов.
# 4. Преобразовать форматы столбцов.
#
# <b>На данном этапе, предобработку считаю завершенной. Осталось посмотреть сколько данных мы выбросили из выборки.</b>

# %%
del_count[0]/23699*100
# Out:
# 0.9578463226296469

# %% [markdown]
# <b>В выборке большое количество столбцов, поэтому выбрасывая большое количество строк, мы теряем очень много полезной информации. Выбросили всего 0.96% данных. Капля в море :)</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# <b>Добавим столбец с ценой одного квадратного метра и округлим до рублей.</b>

# %%
data['price_sq_meter'] = data['last_price']/data['total_area']
data['price_sq_meter'] = data['price_sq_meter'].round()

# %% [markdown]
# <b>Добавим столбцы с номером дня недели публикации, месяца публикации и года публикации.</b>

# %%
data['week_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Совет на будущие работы: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
#
# Этот метод нужен для визуализации динамики по неделям, месяцам или годам (смотря какой метод выберешь)
#
# Код выглядит так:
#
#         df['first_day_exposition'].dt.date #приводим к временному формату
#         df['first_day_exposition'].astype('datetime64[M]')
#
# Если года разные, то в новой колонке месяца у тебя отобразится первый день месяца ('2019-05-01')
# </div>

# %% [markdown]
# <b>Добавим столбец в категорией этажа квартиры "первый", "последний", "другой". Напишем функцию и применим ее к нашему датафрейму.</b>

# %%
def floor_category(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

# %%
data['floor_category'] = data.apply(floor_category, axis = 1)

# %% [markdown]
# <b>Добавим столбец с расстоянием до центра города в км. </b>

# %%
data['city_centers_nearest_km'] = data['city_centers_nearest'] / 1000
data['city_centers_nearest_km']= data['city_centers_nearest_km'].round()

# %% [markdown]
# <b>Посмотрим первые 10 строк датафрейма с добавленными столбцами и посмотрим информацию. </b>

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000      108.00           2019-03-07      3
# 1             7     3350000       40.40           2018-12-04      1
# 2            10     5196000       56.00           2015-08-20      2
# 3             0    64900000      159.00           2015-07-24      3
# 4             2    10000000      100.00           2018-06-19      2
# 5            10     2890000       30.40           2018-09-10      1
# 6             6     3700000       37.30           2017-11-02      1
# 7             5     7915000       71.60           2019-04-18      2
# 8            20     2900000       33.16           2018-05-23      1
# 9            18     5400000       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16    51.000000      8         False   False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23472 entries, 0 to 23698
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23472 non-null  int64
#  1   last_price               23472 non-null  int64
#  2   total_area               23472 non-null  float64
#  3   first_day_exposition     23472 non-null  datetime64[ns]
#  4   rooms                    23472 non-null  int64
#  5   ceiling_height           23472 non-null  float64
#  6   floors_total             23472 non-null  int64
#  7   living_area              23472 non-null  float64
#  8   floor                    23472 non-null  int64
#  9   is_apartment             23472 non-null  bool
#  10  studio                   23472 non-null  bool
#  11  open_plan                23472 non-null  bool
#  12  kitchen_area             23472 non-null  float64
#  13  balcony                  23472 non-null  int64
# ...

# %% [markdown]
# <b>Как итог, мы рассчитали новые столбца, которые позволят нам проводить исследовательский анализ.
# Стоит отметить, что пропуски в столбце floors_total мы удалили на предыдущих шагах. Поэтому новый столбец floor_category не содержит пропусков. А в столбце city_centers_nearest_km пропуски имеются, так как мы не убирали их в столбце city_centers_nearest.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Отлично! Приступим к исследовательскому анализу.
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# <b>Изучим параметры объектов недвижимости нашего датафрейма.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца total_area.
# Рассчитаем квантили и построим гистограмму.</b>

# %%
data['total_area'].describe().T
# Out:
# count    23472.000000
# mean        60.396417
# std         35.669788
# min         17.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data['total_area'].hist(bins=30, range=(data['total_area'].min(),data['total_area'].quantile(.95)), ec='black',figsize=(10, 10), legend=True)
plt.title('общая площадь')
plt.xlabel('м²')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Наиболее продаваемая недвижимость с метражом 40-69 квадратов. Среднее значение - 60 м, а медианное 52, это говорит о том, что больших квартир продается больше чем маленьких.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Верно, с большей площадью меньше предложений. Объекты выше 90-100 кв. м - это более дорогой сегмент.
# </div>

# %% [markdown]
# <b>Посмотрим стратистику для столбца living_area.
# Рассчитаем квантили и построим гистограмму.</b>

# %%
data['living_area'].describe().T
# Out:
# count    23472.000000
# mean        35.240460
# std         23.036411
# min         10.000000
# 25%         19.000000
# 50%         30.400000
# 75%         42.965517
# max        435.172414
# Name: living_area, dtype: float64

# %%
data['living_area'].hist(bins=30, range=(data['living_area'].min(), data['living_area'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('жилая площадь')
plt.xlabel('м²')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Объектов с жилой площадью 17 м - 30 м - большинство. Наблюдаются пики в районе 17 - 19 метров и 25 - 30.
# Среднее значение - 35, медиана 30. У гистограммы имеется хвост справа, за счет редких но высоких значений.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца kitchen_area.
# Рассчитаем квантили и построим гистограмму.</b>

# %%
data['kitchen_area'].describe().T
# Out:
# count    23472.000000
# mean        10.895395
# std          6.502089
# min          4.000000
# 25%          7.100000
# 50%          9.439186
# 75%         12.000000
# max        123.873833
# Name: kitchen_area, dtype: float64

# %%
data['living_area'].hist(bins=30, range=(data['kitchen_area'].min(), data['kitchen_area'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('площадь кухни')
plt.xlabel('м²')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Наиболее встречаемые варианты с площадью кухни 5 м - 12 м. Среднее - 10.9, медиана - 9.4. Имеется небольшой хвост за счет того, что объекты с большими кухнями встречаются чаще, чем с маленкими.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца last_price.
# Рассчитаем квантили и построим гистограмму.</b>

# %%
data['last_price'].describe().T
# Out:
# count    2.347200e+04
# mean     6.541618e+06
# std      1.089918e+07
# min      1.219000e+04
# 25%      3.420000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
data['last_price'].hist(bins=30, range=(data['last_price'].min(), data['last_price'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('последняя цена')
plt.xlabel('10 млн.руб')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Средняя цена объектов недвижимости - 6.54 млн руб, медиана - 4.65 млн руб. Имеется хвост справа, так как объектов с высокой ценой больше, чем объектов с низкой. Это объяснется и тем, что подобный хвост наблюдается и на гистограммах с общей и жилой площадями.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца rooms.
# Рассчитаем квантили и построим гистограмму.</b>

# %%
data['rooms'].describe().T
# Out:
# count    23472.000000
# mean         2.072981
# std          1.078804
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
data['rooms'].hist(bins=5, range=(1, data['rooms'].quantile(.99)), ec='black', figsize=(10, 10), legend=True)
plt.title('количество комнат объекта недвижимости')
plt.xlabel('комнаты')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Наиболее встречаемые варианты - 1,2 комнаты. Чуть реже - 3 комнаты. Медианное и среднее значения крайне близки. Следовательно выбросы не оказывают влияния на статистику.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍Однокомнатные популярней по ряду причин: цена(доступней для одиноких людей, а также людям в гражданском браке), рентабельность(покупка с целью продать дороже, а так же сдача в наём для приезжих, студентов и т.д), наследство.
# </div>

# %% [markdown]
# <b>Посмотрим стратистику для столбца ceiling_height.
# Рассчитаем квантили и построим гистограмму. </b>

# %%
data['ceiling_height'].describe().T
# Out:
# count    23472.000000
# mean         2.696512
# std          0.220044
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          5.600000
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist(bins=10, range=(data['ceiling_height'].quantile(.05), data['ceiling_height'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('Высота потолков объектов недвижимости')
plt.xlabel('метры (м)')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Большинство объектов недвижимости имеют высоту потолков 2,5 м и 2,65 м. Реже представлены варианты от 2,7м до 2,85 м. Среднее 2,7 м и медиана 2,65 почти совпадают, что говорит о том, что выбросы не влияют на статистику.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца floor.
# Рассчитаем квантили и построим гистограмму.</b>

# %%
data['floor'].describe().T
# Out:
# count    23472.000000
# mean         5.876832
# std          4.867574
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          8.000000
# max         33.000000
# Name: floor, dtype: float64

# %%
data['floor'].hist(bins=10, range=(data['floor'].min(), data['floor'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('этаж объектов недвижимости')
plt.xlabel('этаж')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Наиболее встречаемые варианты с 1 по 4 этаж. Чуть реже представлены варианты с 5-7 этаж. Среднее значение 6, медианное 4.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца floor_category и построим гистограмму.</b>

# %%
pivot_floor_category = data['floor_category'].value_counts()/len(data['floor_category'])# Рассчитаем долю каждой категории
pivot_floor_category.columns = ['category', 'count']
pivot_floor_category
# Out:
# другой       0.735387
# последний    0.141317
# первый       0.123296
# Name: floor_category, dtype: float64

# %%
data_names = ['другой', 'последний', 'первый']
plt.pie(
    pivot_floor_category, autopct='%.1f', radius = 1.1,
    explode = [0.15] + [0 for _ in range(len(data_names) - 1)] )
plt.legend(
    bbox_to_anchor = (-0.16, 0.45, 0.25, 0.25),
    loc = 'best', labels = data_names )
plt.show()

# %% [markdown]
# <b>Доля "не первого и не последнего этажа" - 73%. Доля Первый и последние этажа очень близки.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍 Да, чаще всего продают не последний и не первый этажи - такие этажи могут быть проблемными (заглядывают прохожие, холодно, жарко, протекает крыша и т.д.)
#
# Также это связано с этажностью строительства. Первый и последний этажи - это лишь по одному этажу, а группа "другой" включает в себя все этажи, кроме первого и последнего. Для 3-этажных домов мы бы увидели равномерное распределение, но строительство заметно выше, чем 3 этажа.
# </div>

# %% [markdown]
# <div class="alert alert-danger" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# ✍
# Здорово, что мы показываем соотношение на круговой диагармме, но в таком случае необходимо отобразить и сами доли.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Теперь доли есть на диаграмме :)
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.3</b>
#
# 👍
# Супер!
# </div>

# %% [markdown]
# <b>Посмотрим стратистику для столбца floors_total и построим гистограмму.</b>

# %%
data['floors_total'].describe().T
# Out:
# count    23472.000000
# mean        10.675954
# std          6.588411
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %%
data['floors_total'].hist(bins=10, range=(data['floors_total'].min(), data['floors_total'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('количество этажей в доме')
plt.xlabel('этаж')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Наиболее часто встречаются варианты недвижимости в 5-этажках и 9-этажках.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца city_centers_nearest и построим гистограмму.</b>

# %%
data['city_centers_nearest'].describe().T
# Out:
# count    17988.000000
# mean     14202.503502
# std       8613.983281
# min        181.000000
# 25%       9247.000000
# 50%      13104.500000
# 75%      16293.000000
# max      65968.000000
# Name: city_centers_nearest, dtype: float64

# %%
data['city_centers_nearest'].hist(bins=30, range=(data['city_centers_nearest'].min(), data['city_centers_nearest'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('расстояние до центра')
plt.xlabel('м')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Среднее 14 км, медиана 13 км. Вариантов, которые ближе к центру чуть больше.</b>

# %%
data['airports_nearest'].describe()
# Out:
# count    17965.000000
# mean     28805.086780
# std      12638.850968
# min          0.000000
# 25%      18552.000000
# 50%      26757.000000
# 75%      37294.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %%
data['airports_nearest'].hist(bins=15, range=(data['airports_nearest'].min(), data['airports_nearest'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('расстояние до аэропорта')
plt.xlabel('м')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Наибольшее количество объектов недвижимости находится на расстоянии 18 - 37 км от аэропортов. Среднее 28.8 и медиана 26.8 км. Вариантов, которые ближе к аэропорту чуть больше.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца parks_nearest и построим гистограмму.</b>

# %%
data['parks_nearest'].describe().T
# Out:
# count    7996.000000
# mean      490.412581
# std       341.579581
# min         1.000000
# 25%       287.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %%
data['parks_nearest'].hist(bins=15, range=(data['parks_nearest'].min(), data['parks_nearest'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>Большинство объектов недвижимости расположены на расстоянии 400-600 метров от парков. Среднее - 490, медиана 455. Вариантов ближе к паркам чуть больше.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца week_exposition и построим гистограмму.</b>

# %%
data['week_exposition'].value_counts()
# Out:
# 3    4263
# 1    4147
# 4    3966
# 2    3928
# 0    3576
# 5    1916
# 6    1676
# Name: week_exposition, dtype: int64

# %%
data['week_exposition'].value_counts().plot.bar(figsize=(7, 5), ec='black', legend=True)
plt.show()

# %% [markdown]
# <b>Чаще всего объявлению выкладываются в будние дни.</b>

# %% [markdown]
# <b>Посмотрим стратистику для столбца month_exposition и построим гистограмму.</b>

# %%
data['month_exposition'].value_counts()
# Out:
# 2     2621
# 3     2565
# 11    2355
# 4     2351
# 10    2098
# 9     1967
# 6     1741
# 8     1729
# 7     1674
# 12    1630
# 1     1482
# 5     1259
# Name: month_exposition, dtype: int64

# %%
data['month_exposition'].value_counts().plot.bar(figsize=(7, 5), ec='black', legend=True)
plt.show()

# %% [markdown]
# <b>Чаще всего обявления выкладывают в феврале и марте. Наименьшие показатели в мае и январе. Таким образом, можно сказать, что меньше всего выкладыывают объявлений в месяца с большим количеством выходных и праздников.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍  В целом, праздничные месяцы отличаются меньшим предложением. Это нормально.
# </div>

# %% [markdown]
# <b>Вывод: после просмотра статистики по столбцам и построения диаграмм мы получили представление о типичном объекте недвижимости. Это однушка или двушка в пяти или девятиэтажке. Общая площадь - 40м² - 69м². Площадь кухни - 5м² - 12м². Высота потолков 2.5м - 2.65м . Расстояние до центра около 13 км, до аэропортов 15км - 25 км, до парка - 400м - 600м . Квартиры обычно выкладываются в рабочие дни.</b>

# %% [markdown]
# <b>Теперь изучим, как быстро продавались объекты недвижимости.</b>

# %%
data['days_exposition'].describe().T
# Out:
# count    20312.000000
# mean       180.917093
# std        219.995022
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(bins=100, range=(data['days_exposition'].min(), data['days_exposition'].quantile(.95)), ec='black', figsize=(10, 10), legend=True)
plt.title('время продажи квартиры')
plt.xlabel('дни')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Видим два пика до 70 дней. Посмотрим гистограмму до 70 дней.</b>

# %%
data['days_exposition'].hist(bins=70, range=(0, 70), figsize=(7, 5), ec='black', legend=True)
plt.title('время продажи объекта квартиры')
plt.xlabel('дни')
plt.ylabel('объекты недвижимости')
plt.show()

# %% [markdown]
# <b>Видим пики в 45 и 60 дней. Среднее значение 181 день, медианное 95. У гистограммы виден длинный хвост. Отклонение больше среднего значения. Все это говорит о большом количестве выбросов. Стоит помнить, что снятие объекта с продажи на сайте может быть не связано с его продажей. Возможно, истек срок размещения объявления и его необходимо продлить. Длинный хвост может быть связан с тем, что объявления забывают снять с публикации.</b>

# %% [markdown]
# <b>Построим диграмму "ящик с усами".</b>

# %%
data.boxplot(column='days_exposition', figsize=(8, 6))
plt.title('Размах времени продажи объекта недвижимости')
plt.ylim(data['days_exposition'].min(), data['days_exposition'].max())
plt.ylabel('дни')
plt.show()

# %%
data['days_exposition'].quantile(.9)
# Out:
# 460.0

# %%
print(data['days_exposition'].quantile(.75) + 1.5 * (data['days_exposition'].quantile(.75)-data['days_exposition'].quantile(.25)))
# Out:
# 510.0

# %% [markdown]
# <b>Можно сказать, что объявления, которые "висят" дольше 510 дней - это выбросы. Очень быстрыми продажами, можно назвать объекты проданные менее чем за 45 дней. Обычные продажи - 46 - 231 день. 231 - 510 - долгие продажи.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.1</b>
#
# 👍  Верно
# </div>

# %% [markdown]
# <b>Рассмотрим факторы, которые больше всего влияют на цену недвижимости.</b>

# %%
corr_param = ['last_price','total_area', 'living_area', 'kitchen_area', 'rooms', 'week_exposition', 'month_exposition', 'year_exposition']

# %% [markdown]
# <b>Выведем матрицу корреляции.</b>

# %%
corr_matrix = data[corr_param].corr()
corr_matrix
# Out:
#                   last_price  total_area  living_area  kitchen_area     rooms  \
# last_price          1.000000    0.653905     0.585075      0.519152  0.363340
# total_area          0.653905    1.000000     0.944954      0.657384  0.758515
# living_area         0.585075    0.944954     1.000000      0.534847  0.815637
# kitchen_area        0.519152    0.657384     0.534847      1.000000  0.323300
# rooms               0.363340    0.758515     0.815637      0.323300  1.000000
# week_exposition     0.001974   -0.005892    -0.001865      0.001545 -0.005414
# month_exposition    0.002447    0.005158    -0.001470      0.001676 -0.003722
# year_exposition    -0.042211   -0.078593    -0.065123     -0.054614 -0.054246
#
#                   week_exposition  month_exposition  year_exposition
# last_price               0.001974          0.002447        -0.042211
# total_area              -0.005892          0.005158        -0.078593
# ...

# %% [markdown]
# <b>Уже по матрице корелляций мы можем сделать определенные выводы о зависимости цены от параметров, но еще лучше эта зависимость будет показана на графике heatmap.</b>

# %%
plt.figure(figsize = (15, 10))
sns.heatmap(corr_matrix, vmin=-1, vmax=1,
            cmap='coolwarm', annot=True,
            )
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# <b>Вывод 1: Из графика видно, что самая сильная связь наблюдается у пары последней цены и общей площадью (чем больше метраж квартиры, тем выше ее стоимость). Чуть меньшей связью обладает пара последняя цена и жилая площадь, так как корелляция между общей и жилой площадью почти единица. Связь между ценой и площадью кухни тоже прослеживается и также за счет корелляции с общей и жилой площадью. Аналогичная ситуация и с количеством комнат.</b>

# %% [markdown]
# <b>Нарисуем еще несколько графиков методом scatter.</b>

# %%
data.plot(x='total_area', y ='last_price', kind ='scatter', figsize=(8, 6), legend=True, alpha = 0.03)

plt.title('зависимость жилой площади от стоимости квартиры')
plt.xlabel('площадь, м²')
plt.ylabel('стоимость, 10 млн.руб.')
plt.ylim(0, 40000000)
plt.show()

# %%
data.plot(x='living_area', y ='last_price', kind ='scatter', figsize=(8, 6), legend=True, alpha = 0.03)

plt.title('зависимость жилой площади от стоимости квартиры')
plt.xlabel('площадь, м²')
plt.ylabel('стоимость, 10 млн.руб.')
plt.ylim(0, 40000000)
plt.show()

# %%
data.plot(x='kitchen_area', y ='last_price', kind ='scatter', figsize=(8, 6), legend=True, alpha = 0.03)

plt.title('Зависимость площади кухни от стоимости квартиры')
plt.xlabel('площадь, м²')
plt.ylabel('стоимость, 10 млн.руб.')
plt.ylim(0, 40000000)
plt.show()

# %%
week_price = data.pivot_table(index='week_exposition', values='last_price')
month_price = data.pivot_table(index='month_exposition', values='last_price')
year_price = data.pivot_table(index='year_exposition', values='last_price')

fig, ax = plt.subplots(3, figsize = (15, 10))
ax[0].plot(week_price.index, week_price['last_price'])
ax[1].plot(month_price.index, month_price['last_price'])
ax[2].plot(year_price.index, year_price['last_price'])

ax[0].set(xlabel='День недели', ylabel='Стоимость квартир, тыс. руб', 
          title='Распределение стоимости всей квартиры по дням недели')
ax[1].set(xlabel='Месяц', ylabel='Стоимость квартир, тыс. руб', 
          title='Распределение стоимости всей квартиры по месяцам', xticks=month_price.index)
ax[2].set(xlabel='Месяц', ylabel='Стоимость квартир, тыс. руб', 
          title='Распределение стоимости всей квартиры по годам', xticks=year_price.index)

ax[0].grid()
ax[1].grid()
plt.subplots_adjust(wspace = 0.3, hspace = 0.4) 
plt.show()

# %%
data.plot(x = 'rooms', y = 'last_price', style='o', grid=True, figsize=(12, 6), alpha=0.05)
plt.title('Зависимость кол-ва комнат от стоимости квартиры')
plt.xlabel('кол-во комнат')
plt.ylabel('стоимость, 100 млн.руб.')
plt.ylim(0, 100000000)
plt.show()

# %% [markdown]
# <b>Вывод 2: из графиков, можно заключить:</b>
#
# 1. Cильная линейная пропорциональная зависимость между общей площадью, жилой площадью, площадью кухни и ценой квартиры прослеживается до 20 млн.
# 2. Из графика с количеством комнат видно, что больше всего данных для квартир стоимостью до 20 млн. руб и кол-вом комнат от 1 до
# 3. Для этого диапазона: с учеличение числа комнат до 4 комнат стоимость квартир растет, для 5 комнат стоимость снижается. Это можно объяснить тем, что в старом фонде есть 5-ти комнатные квартиры с маленькой площадью комнат или тем, что такие квартиры неликвидны и требуют большую скидку для продажи.
# 4. Явной зависимость между датой публикации и ценой квартиры нет. Тот же результат показала нам матрица корелляции с коэффициентами корелляции по данным параметрам и ценой. Однако, с каждым годом, цена квартир снижается.

# %% [markdown]
# <b>Посмотрим график зависимости стоимости квартиры от категории этажа.</b>

# %%
pivot_table_floor_category = data.pivot_table(index = 'floor_category', values = 'last_price', aggfunc = ['mean', 'count', 'median'])
pivot_table_floor_category.plot(y = 'median', legend=True)
pivot_table_floor_category
# Out:
#                         mean      count     median
#                   last_price last_price last_price
# floor_category
# другой          6.683259e+06      17261    4850000
# первый          4.812374e+06       2894    3900000
# последний       7.313265e+06       3317    4300000

# %% [markdown]
# <b>Вывод 3: из графика видно, что мединное значение цен квартир на первом этаже - самое низакое. Самое высокое - для квартир, находящихся на этаже отличном от первого и последнего.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍  Верная интерпретация полученных данных.
# </div>

# %% [markdown]
# <b>Теперь, посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений и выделим населенные пункты с самой низкой и самой высокой ценой за кв.м.</b>

# %%
top_ten_loc = data['locality_name'].value_counts().head(10)
top_ten_loc
# Out:
# Санкт-Петербург      15581
# посёлок Мурино         581
# Кудрово                470
# посёлок Шушары         438
# Всеволожск             398
# Пушкин                 368
# Колпино                338
# посёлок Парголово      327
# Гатчина                306
# Выборг                 237
# Name: locality_name, dtype: int64

# %%
top_ten_loc_pivot = data.query('locality_name in @top_ten_loc.index').pivot_table(index='locality_name', values='price_sq_meter')
top_ten_loc_pivot.sort_values(by='price_sq_meter', ascending=False)
# Out:
#                    price_sq_meter
# locality_name
# Санкт-Петербург     114728.152044
# Пушкин              103081.146739
# Кудрово              95260.872340
# посёлок Парголово    90175.886850
# посёлок Мурино       85923.142857
# посёлок Шушары       78577.029680
# Колпино              75424.571006
# Гатчина              68757.643791
# Всеволожск           68654.474874
# Выборг               58141.919831

# %%
top_ten_loc_pivot.sort_values(by='price_sq_meter').plot(kind='barh', legend=True, grid=True, ec='black', figsize=(8, 6))

plt.title('Средняя цена за м²')
plt.xlabel('руб/м²')
plt.show()

# %% [markdown]
# <b>Вывод 4: из гистограммы видно, что самая высокая цена за кв.м. в Санкт-Петербурге. Это выглядит вполне логично. За ним идет Пушкин - крупный туристический, научный, учебный и военно-промышленный центр. Включён в список памятников, охраняемых ЮНЕСКО. На последнем месте топа находится Выборг, что может быть связано с удаленностью от СПБ, запущенностью города и большим количеством старых и полуразрушенных частных домов (взято из отзывов).</b>

# %% [markdown]
# <div class="alert alert-warning" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 📝
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам.
#
#
#
# </div>

# %% [markdown]
# <b>Ранее мы посчитали расстояние до центра в километрах. Теперь выделим квартиры в Санкт-Петербурге и вычислим среднюю цену каждого километра.</b>

# %%
data_spb = data.query('locality_name == "Санкт-Петербург"')

# %%
data_spb.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20    13000000       108.0           2019-03-07      3
# 2             10     5196000        56.0           2015-08-20      2
# 3              0    64900000       159.0           2015-07-24      3
# 4              2    10000000       100.0           2018-06-19      2
# 7              5     7915000        71.6           2019-04-18      2
# 9             18     5400000        61.0           2017-02-26      3
# 10             5     5050000        39.6           2017-11-16      1
# 15            16     4650000        39.0           2017-11-18      1
# 16            11     6700000        82.0           2017-11-23      3
# 17             6     4180000        36.0           2016-09-09      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0             2.70            16    51.000000      8         False   False
# ...

# %%
data_spb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15581 entries, 0 to 23697
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             15581 non-null  int64
#  1   last_price               15581 non-null  int64
#  2   total_area               15581 non-null  float64
#  3   first_day_exposition     15581 non-null  datetime64[ns]
#  4   rooms                    15581 non-null  int64
#  5   ceiling_height           15581 non-null  float64
#  6   floors_total             15581 non-null  int64
#  7   living_area              15581 non-null  float64
#  8   floor                    15581 non-null  int64
#  9   is_apartment             15581 non-null  bool
#  10  studio                   15581 non-null  bool
#  11  open_plan                15581 non-null  bool
#  12  kitchen_area             15581 non-null  float64
#  13  balcony                  15581 non-null  int64
# ...

# %%
data_spb.pivot_table(index='city_centers_nearest_km', values='price_sq_meter').plot(marker='o', grid=True, figsize=(8, 6), legend=False)
plt.title('Средняя цена квадратного метра\nс шагом в 1 км до центра')
plt.xlabel('км')
plt.ylabel('руб./м²')
plt.show()

# %% [markdown]
# <b>Вывод 5: Из графика следует, что после 8 км от центра СПБ прослеживается сильная зависимость, похожая на линейную. Затем наблюдается небольшая смена тренда на расстоянии 3-8 км. У объектов, расположенных на расстоянии менее 3 км до центра намечается резкий рос цены, по мере приближения к центру. Общий тренд такой: Чем дальше от центра СПБ квартира, тем меньше ее стоимость.
# Однако на 27 км заметен явный пик.</b>

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍  Верно, дальше от центра - дешевле квартиры.
# </div>

# %%
data_spb.query('city_centers_nearest_km == 27')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 748             13    14350000        74.0           2017-11-28      2
# 5961             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 748             3.13             5         30.0      3         False   False
# 5961            2.65             2         16.5      2         False   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 748       False          25.0        0  Санкт-Петербург           23888.0
# 5961      False           7.0        0  Санкт-Петербург           24006.0
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 748                27313.0                1.0         1496.0
# 5961               27431.0                0.0            NaN
#
#       ponds_around_3000  ponds_nearest  days_exposition  price_sq_meter  \
# ...

# %% [markdown]
# <b>По данному расположению от центра есть всего 2 строки. Причем, стоимость за квадратный метр одной из них, хорошо бы описывала нашу выявленную зависиость. Следовательно, это не жилье класса "Премиум". Возможно здесь жил выдающийся человек, и стоимость квартиры-музея завышена из-за этого или сделан очень дорогостоящий ремонт.</b>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# - Наибольшеее влияние на стоимость квартиры оказывает общая площадь. Чуть меньшее влияние жилая площадь, площадь кухни и количество комнат. На первом этаже квартиры продаются дешевле всего. Самые дорогие относятся к категории "не первый не последний этаж". Дата размешения (день недели, месяц, год) никак не влияет на цену недвижимости.
# - Сильная линейная зависимость цены от площади  прослеживается до цены недвижимости 20 млн.руб.
# - Типичная квартира, продаваемая в Л.О. и Санкт-Петербурге: однушка или двушка в пяти или девятиэтажке. Общая площадь - 40м² - 69м². Площадь кухни - 5м² - 12м². Высота потолков 2.5м - 2.65м . Расстояние до центра около 13 км, до аэропортов 15км - 25 км, до парка - 400м - 600м .
# - Квартиры обычно выкладываются в рабочие дни.
# - Обычно квартиры продаются в течении 46 - 231 дня. Быстрыми можно назвать - продажи до 45 дней. Медленными - 231 - 510 дней.
# - Стоимость квартир возрастает по мере приближения расположения к центру города. Однако, на отметке 8 км и ближе эта зависимость ослабевает вплоть до 3 км. Затем наблюдается сильный рост цены по мере приближения к центру.
# - Самая высокая цена за квадратный метр - в Санкт-Петербурге (114728 руб./м²). Самая низкая - в Выборге(58142 руб./м²).

# %% [markdown]
# <div class="alert alert-success" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий ревьюера v.2</b>
#
# 👍
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# Ты очень серьезно подходишь к визуализации.
#
# Вот пара ссылок на полезные источники:https://habr.com/ru/company/otus/blog/540526/, https://pythonru.com/biblioteki/seaborn-plot
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.1</b>
#
# 👋
# Кирилл, замечательная работа.  Я оставил несколько обязательных поправок для тебя и после этого буду готов сразу принять проект.
#
# Удачи в доработках, жду!

# %% [markdown]
# <div class="alert alert-info" style="border-radius: 10px; box-shadow: 2px 2px 2px; border: 1px solid; padding: 10px ">
# <b>Комментарий студента</b>
#
# Спасибо за ревью, ошибки исправил.
# </div>

# %% [markdown]
# <div style="border:solid indigo 3px; padding: 20px">
# <div class="alert alert-success">
# <b>Обратная связь v.2</b>
#
# 👋
#
# Кирилл, спасибо тебе за исправления критических моментов, а также спасибо за хорошую работу.
#
# Поздравляю с успешным завершением проекта.
#
# И желаю успехов в новых работах.

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
