# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Кирилл :) Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил бонус

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Кирилл :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
#  # Анализ продаж компьютерных игр в интернет-магазине "Стримчик"

# %% [markdown]
# <h1> Описание проекта: </h1>
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# <h1> Описание данных </h1>

# %% [markdown]
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# # План проекта

# %% [markdown]
# 1. Откройте файл с данными и изучите общую информацию
# 2. Подготовим данные:
#     - Заменим названия столбцов (приведем к нижнему регистру);
#     - Преобразуем данные в нужные типы. Опишем, в каких столбцах заменили тип данных и почему;
#     - Обработаем пропуски:
#     - Посчитаем суммарные продажи во всех регионах и запишите их в отдельный столбец.
# 3. Проведите исследовательский анализ данных
#     - Посмотрим, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#     - Посмотрим, как менялись продажи по платформам. Выберем платформы с наибольшими суммарными продажами и построим распределение по годам. Определим, за какой характерный срок появляются новые и исчезают старые платформы?
#     - Возьмитм данные за соответствующий актуальный период.
#     - Определим, какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#     - Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам.
#     - Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами.
#     - Соотнесем выводы с продажами игр на других платформах.
#     - Посмотрим на общее распределение игр по жанрам.
# 4. Составим портрет пользователя каждого региона. Определим для пользователя каждого региона (NA, EU, JP):
#     - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#     - Самые популярные жанры (топ-5).
#     - Проверим, влияет ли рейтинг ESRB на продажи в отдельном регионе?
# 5. Напишем общий вывод

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 👍

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Название, краткое вступление в работу и главная задача зафиксированы.
#
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Написал план проекта

# %% [markdown]
# ## check

# %% [markdown]
# # Откроем файл с данными и изучим общую информацию

# %% [markdown]
# Импортируем библиотеки

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %% [markdown]
# Прочитаем данные и запишем их в перменную

# %%
data = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# Выведем информацию о датафрейме

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Запишем изначальное количество строк в датафрейме

# %%
row_in = len(data)
row_in
# Out:
# 16715

# %% [markdown]
# Выведем первые 10 строк датафрейма

# %%
data.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#    NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     41.36     28.96      3.77         8.45          76.0          8      E
# ...

# %% [markdown]
# Посмотрим статистическую сводку по числовым столбцам датафрейма

# %%
data.describe().T
# Out:
#                    count         mean        std     min     25%      50%  \
# Year_of_Release  16446.0  2006.484616   5.877050  1980.0  2003.0  2007.00
# NA_sales         16715.0     0.263377   0.813604     0.0     0.0     0.08
# EU_sales         16715.0     0.145060   0.503339     0.0     0.0     0.02
# JP_sales         16715.0     0.077617   0.308853     0.0     0.0     0.00
# Other_sales      16715.0     0.047342   0.186731     0.0     0.0     0.01
# Critic_Score      8137.0    68.967679  13.938165    13.0    60.0    71.00
#
#                      75%      max
# Year_of_Release  2010.00  2016.00
# NA_sales            0.24    41.36
# EU_sales            0.11    28.96
# JP_sales            0.04    10.22
# Other_sales         0.03    10.57
# Critic_Score       79.00    98.00

# %% [markdown]
# Посмотрим количество и долю пропусков данных в столбцах

# %%
pd.DataFrame(round(data.isna().mean()*100,1)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_428bb_row0_col0,#T_428bb_row1_col0,#T_428bb_row3_col0,#T_428bb_row4_col0,#T_428bb_row5_col0,#T_428bb_row6_col0,#T_428bb_row7_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_428bb_row2_col0{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_428bb_row8_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_428bb_row9_col0{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_428bb_row10_col0{
#             background-color:  #ef886b;
#             color:  #000000;
#         }</style><table id="T_428bb_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_428bb_level0_row0" class="row_heading level0 row0" >Name</th>
# ...

# %%
pd.DataFrame(round(data.isna().sum())).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_746dc_row0_col0,#T_746dc_row1_col0,#T_746dc_row3_col0,#T_746dc_row4_col0,#T_746dc_row5_col0,#T_746dc_row6_col0,#T_746dc_row7_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_746dc_row2_col0{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_746dc_row8_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_746dc_row9_col0{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_746dc_row10_col0{
#             background-color:  #f08a6c;
#             color:  #000000;
#         }</style><table id="T_746dc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_746dc_level0_row0" class="row_heading level0 row0" >Name</th>
# ...

# %% [markdown]
# Видим большое количество пропусков в столбцах Critic_Score, User_Score, Rating. Посмотрим поподробнее эти столбцы.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не хватает меток данных с числом пропусков

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100
#
#         plt.xlim(0, 100)

# %%
data['Critic_Score'].value_counts()
# Out:
# 70.0    256
# 71.0    254
# 75.0    245
# 78.0    240
# 73.0    238
#        ...
# 29.0      3
# 13.0      1
# 22.0      1
# 17.0      1
# 21.0      1
# Name: Critic_Score, Length: 82, dtype: int64

# %%
data['User_Score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 2.3       2
# 1         2
# 9.6       2
# 0         1
# 9.7       1
# Name: User_Score, Length: 96, dtype: int64

# %%
data['Rating'].value_counts()
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: Rating, dtype: int64

# %% [markdown]
# Вывод по исходным данным:
# 1. Необходимо привести названия столбцов к змеиному регистру
# 2. Необходимо изменить тип данных для столбцов:
#     - Year_of_Release integer
#     - Critic_Score int
#     - User_Score float (предварительно, разобраться, что такое tbd и на что его можно заменить)
# 3. Разобраться с пропусками данных в столбцах:
#     - Name
#     - Year_of_Release
#     - Genre
#     - Critic_Score
#     - User_Score (разобраться, что такое tbd и на что его можно заменить)
#     - Rating
# 4. Проверить на наличие явных и неявных дубликатов

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно, отличный промежуточный вывод

# %% [markdown]
# ## check

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Переименуем столбцы (приведем к змеиному регистру)

# %%
data = data.rename(columns={'Name': 'name', 
                            'Platform': 'platform', 
                            'Year_of_Release': 'year_of_release',
                            'Genre': 'genre',
                            'NA_sales': 'na_sales',
                            'EU_sales': 'eu_sales',
                            'JP_sales': 'jp_sales',
                            'Other_sales': 'other_sales',
                            'Critic_Score': 'critic_score',
                            'User_Score': 'user_score',
                            'Rating': 'rating',
                           })

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />можно
#
#     games.columns = games.columns.str.lower()

# %% [markdown]
# Проверим на наличие явных и неявных дубликатов

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Удалил эти дубликаты ниже

# %% [markdown]
# Посмотрим дубликаты по сумме параметров name, platform, year_of_release

# %%
data[data[['name','platform', 'year_of_release']].duplicated() == True]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 14244            NaN      GEN           1993.0     NaN       0.0      0.00
# 16230  Madden NFL 13      PS3           2012.0  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score user_score rating
# 14244      0.03          0.0           NaN        NaN    NaN
# 16230      0.00          0.0          83.0        5.5      E

# %% [markdown]
# Найдены 2 неявных дубликата, которые не повлияют на анализ. Можно удалить.

# %%
data = data[data[['name','platform', 'year_of_release']].duplicated() == False]

# %%
data['genre'].value_counts()
# Out:
# Action          3369
# Sports          2347
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: genre, dtype: int64

# %%
# pd.set_option('display.max_rows', None)
data.sort_values(by = ['name'])['name']
# Out:
# 14983                  Beyblade Burst
# 1079                Fire Emblem Fates
# 3862             Frozen: Olaf's Quest
# 3358             Frozen: Olaf's Quest
# 13794      Haikyu!! Cross Team Match!
#                      ...
# 15612    uDraw Studio: Instant Artist
# 8280     uDraw Studio: Instant Artist
# 475        wwe Smackdown vs. Raw 2006
# 9134     ¡Shin Chan Flipa en colores!
# 659                               NaN
# Name: name, Length: 16713, dtype: object

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не стоит использовать данный параметр на проекте
#
#         pd.set_option('max_rows', None)
#
# в случае миллиона строк мы значительно нагрузим вычислительные ресурсы
#
# отлично, что сбрасываешь параметр
#
#         pd.reset_option('display.max_rows')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Понял, принял :)

# %%
data['platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1330
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       28
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: platform, dtype: int64

# %% [markdown]
# Посмотрим еще раз на столбец user_score

# %%
pd.reset_option('display.max_rows')
data['user_score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 2.3       2
# 1         2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# TBD — это аббревиатура, которая обозначает «To Be Determined»
# Источник: https://psk-group.su/znacheniya/cto-oznacaet-sokrashhenie-tbd
#
# Значит, оценок игроков еще не хватает или производится рассчет рейтинга.
# Такие значения, мы не можем удалить или заменить на медиану.
#
# Можно предположить, что пропуски в этом столбце и в столбце critic_score на значения, которые не могут появлять при других обстоятельствах. Например: -1.

# %%
data.loc[data['user_score']=='tbd', 'user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Скажи пожалуйста, какое преимущество ты получаешь от заполнения пропусков?

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Никакого, уберу данный блок

# %% [markdown]
# Посмотрим на пропуски в столбце name

# %%
data.query('name.isnull()')
# Out:
#     name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659  NaN      GEN           1993.0   NaN      1.78      0.53       0.0
#
#      other_sales  critic_score user_score rating
# 659         0.08           NaN        NaN    NaN

# %% [markdown]
# Здесь пропуски и в столбце name и в столбце genre. Можем удалить строку из датафрейма.

# %%
data = data.query ('~name.isnull()')

# %% [markdown]
# Посмотрим пропуски в столбце year_of_releace

# %%
data.query ('year_of_release.isnull()')
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %% [markdown]
# Имеем 269 пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />проверим корректность алгоритма заполнения пропусков

# %%
# check
# жизненный срок платформы

years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
years_of_life.columns=['min','max']
years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
years_of_life
# Out:
#              min     max  years_of_life
# platform
# 2600      1980.0  1989.0            9.0
# 3DO       1994.0  1995.0            1.0
# 3DS       2011.0  2016.0            5.0
# DC        1998.0  2008.0           10.0
# DS        1985.0  2013.0           28.0
# GB        1988.0  2001.0           13.0
# GBA       2000.0  2007.0            7.0
# GC        2001.0  2007.0            6.0
# GEN       1990.0  1994.0            4.0
# GG        1992.0  1992.0            0.0
# N64       1996.0  2002.0            6.0
# NES       1983.0  1994.0           11.0
# NG        1993.0  1996.0            3.0
# PC        1985.0  2016.0           31.0
# PCFX      1996.0  1996.0            0.0
# PS        1994.0  2003.0            9.0
# PS2       2000.0  2011.0           11.0
# PS3       2006.0  2016.0           10.0
# PS4       2013.0  2016.0            3.0
# PSP       2004.0  2015.0           11.0
# PSV       2011.0  2016.0            5.0
# SAT       1994.0  1999.0            5.0
# ...

# %% [markdown]
# Создадим словарь для хранения года выпуска каждой игры и заменим пропущенные значения в столбце year_of_release

# %%
def fill_year_of_release(df):
    year_of_release_dict = df.groupby('name')['year_of_release'].apply(
        lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan).to_dict()
    df['year_of_release'] = df.apply(
        lambda row: year_of_release_dict[row['name']] if pd.isnull(row['year_of_release']) else row['year_of_release'], axis=1)
    return df

# %%
#data = fill_year_of_release(data)

# %%
# check
# жизненный срок платформы

#years_of_life = data.pivot_table(index='platform',values='year_of_release',aggfunc=['min','max'])
#years_of_life.columns=['min','max']
#years_of_life['years_of_life']=years_of_life['max']-years_of_life['min']
#years_of_life

# %% [markdown]
# Заполнение пропусков данными из словаря искажает информацию о сроке жизни платформы.
# В таком случае, можно посмотреть распределение пропусков по платформам и удалить их, если сами платформы - устаревшие.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Мы внесли искажения в колонку год выпуска игры, которые приводят к ошибкам при определении срока жизни платформ
#
# Стоит посмотреть на платформы, к которым относятся пропуски, __и с легкостью расстанешься с ними ...__
#
# Рекомендуется прежде чем, выполнять проект минут 15-30 посвятить теме анализа (поиск в интернете), чтобы уверенно плавать в океане противоречивых данных :)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Огромное спасибо за такой детальный анализ. Полностью согласен, что замена года релиза на данные из созданного словаря - не очень хорошая идея.

# %% [markdown]
# Посмотрим распределение пропусков года релиза по платформам:

# %%
data.query ('year_of_release.isnull()')['platform'].value_counts()
# Out:
# Wii     34
# PS2     34
# DS      30
# X360    30
# PS3     25
# XB      21
# PC      17
# 2600    17
# PSP     16
# GC      14
# GBA     11
# 3DS      8
# PS       7
# N64      3
# PSV      1
# GB       1
# Name: platform, dtype: int64

# %% [markdown]
# Проверим корректность заполнения. Видим, что большинство платформ - устаревшие, удаление данных из датафрейма не повлияет на дальнейший анализ. Но для начала проверим процент пропусков от общего количества

# %%
round(data.query ('year_of_release.isnull()').count()[0]/len(data)*100,2)
# Out:
# 1.61

# %% [markdown]
# Меньше 2%. Можем безболезненно удалить.

# %%
data = data.query ('~year_of_release.isnull()')

# %% [markdown]
# Посмотрим распределение срока жизни платформы

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Ниже добавлю анализ срока жизни платформы

# %%
years_of_life['years_of_life'].plot(kind = 'bar', figsize = (10,5))
plt.title ('Кол-во выпущенных игр по годам')
plt.xlabel('Год выпуска')
plt.ylabel('Кол-во игр')
plt.show()

# %%
years_of_life['years_of_life'].quantile(.95)
# Out:
# 20.5

# %% [markdown]
# PC - не является игровой платформой. DS, GG, PCFX, TG16 выглядят как выброс. Когда будем формировать срез данных для анализа средней продолжительности жизни платформы, исключим эти платформы из рассмотрения.

# %% [markdown]
# Посмотрим еще раз на столбец rating

# %%
data['rating'].value_counts()
# Out:
# E       3920
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: rating, dtype: int64

# %%
data['rating'].isna().sum()
# Out:
# 6676

# %% [markdown]
# Пропусков в этом столбце очень много. Однако мы не можем причислить их к какой либо группе.
# Таким образом, можно создать еще одну группу "without rating".

# %%
data['rating'] = data['rating'].fillna('without rating')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличное решение для столбца, который содержит категориальные данные, поможет определить ключевое различие в потрете пользователя
#
#         .fillna('without rating')
#
# Можно посмотреть на частотность использования категорий рейтинга, по отношению к остальным
#
#         EC         8
#         K-A        3
#         RP         1
#         AO         1

# %% [markdown]
# Теперь преобразуем типы данных для столбцов
#  - year_of_release integer
#  - critic_score integer
#  - user_score float

# %%
data['year_of_release'] = data['year_of_release'].astype(int)

# %%
data['critic_score'] = data['critic_score'].astype(float)

# %%
data['user_score'] = data['user_score'].astype(float)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> тип данных стоит поменять на целочисленный, если сохранишь заполнение пропусков
#
#        data['critic_score'] = data['critic_score'].astype(float)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Пропуски оставил, так как они не повлияют на наш дальнейший анализ, поэтому оставил тип данных float

# %% [markdown]
# Посмотрим информацию о датафрейме и количество пропусков

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       7462 non-null   float64
#  10  rating           16443 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
pd.DataFrame(round(data.isna().sum())).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_8b42c_row0_col0,#T_8b42c_row1_col0,#T_8b42c_row2_col0,#T_8b42c_row3_col0,#T_8b42c_row4_col0,#T_8b42c_row5_col0,#T_8b42c_row6_col0,#T_8b42c_row7_col0,#T_8b42c_row10_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8b42c_row8_col0{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_8b42c_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_8b42c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b42c_level0_row0" class="row_heading level0 row0" >name</th>
#                         <td id="T_8b42c_row0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Пропуски в стобцах critic_score, user_score не повлияют на наш дальнейший анализ. Можно оставить.

# %% [markdown]
# Рассчитаем долю удаленных данных

# %%
row_out = len(data)
del_ratio = (row_in - row_out) / row_in
del_ratio * 100
# Out:
# 1.6272808854322462

# %% [markdown]
# Добавим новый столбец с суммарными продажами по всем регионам

# %%
data['total_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] +data['other_sales']
data.head(7)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
# 5                    Tetris       GB             1989        Puzzle     23.20
# 6     New Super Mario Bros.       DS             2006      Platform     11.28
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score          rating  \
# 0     28.96      3.77         8.45          76.0         8.0               E
# 1      3.58      6.81         0.77           NaN         NaN  without rating
# 2     12.76      3.79         3.29          82.0         8.3               E
# ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# Вывод: в результате предобработки данных удалось:
#  1. привести названия столбцов к стандартному виду (змеиному регистру)
#  2. изменить тип данных для столбцов, которые являются числовыми (а не категориальными).
#  3. обработать пропуски в столбцах.
#  4. проверить наличие явных и неявных дубликатов и удалить их.
#
# В результате предобработки потеряно 1.62% данных.

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16443 entries, 0 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16443 non-null  object
#  1   platform         16443 non-null  object
#  2   year_of_release  16443 non-null  int64
#  3   genre            16443 non-null  object
#  4   na_sales         16443 non-null  float64
#  5   eu_sales         16443 non-null  float64
#  6   jp_sales         16443 non-null  float64
#  7   other_sales      16443 non-null  float64
#  8   critic_score     7982 non-null   float64
#  9   user_score       7462 non-null   float64
#  10  rating           16443 non-null  object
#  11  total_sales      16443 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ## check

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# Посмотрим, сколько игр выпускалось в каждом году.

# %%
games_per_year = data.groupby('year_of_release')['name'].count()
games_per_year.plot(kind = 'bar', figsize = (10,5))
plt.title ('Кол-во выпущенных игр по годам')
plt.xlabel('Год выпуска')
plt.ylabel('Кол-во игр')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец

# %% [markdown]
# Рассчитаем среднее время жизни платформы: сгруппируем данные по платформе. Вычислим минимальную и максимальную дату релиза и возьмем среднюю разницу между ними.

# %%
def average_platform_lifetime(df):
    platform_lifetimes = df.groupby('platform')['year_of_release'].agg(['min', 'max'])
    platform_lifetimes['lifetime'] = platform_lifetimes['max'] - platform_lifetimes['min']
    avg_lifetime = platform_lifetimes['lifetime'].median()
    return round(avg_lifetime)
platform_slice_lifetime = ['DS', 'GG', 'PCFX', 'TG16', 'PC']
average_platform_lifetime (data.query('platform not in @platform_slice_lifetime'))
# Out:
# 6

# %% [markdown]
# 6 лет - среднее "время жизни" платформы.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию (может повлиять на расчет среднего срока актуальности платформ)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# стоит учесть при расчете отклонения (PC — слишком долго на рынке и не игровая приставка), новые платформы (срок продаж не завершен), выбросы — платформы однодневки

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> И правда! Отсек платформы однодневки и выбросы.

# %% [markdown]
# Посмотрим, как менялись продажи по платформам. Найдем платформы, игр на которые продалось больше всего за последние 4 года.

# %%
data_slice = data.query('year_of_release >=2014')

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#         data_slice = data.query('year_of_release >=2009')

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Взял таймфрейм в 4 года, так как данные за 2016 год еще не закрыт

# %%
total_sales_per_platform = (data_slice.groupby(['platform'],as_index = False)['total_sales'].sum().sort_values(
    'total_sales',ascending = False))

# %% [markdown]
# Cоздадим список платформ

# %%
platform_slice = list(total_sales_per_platform['platform'])

# %% [markdown]
# Cгруппируем данные

# %%
data_grouped = data_slice.groupby(['year_of_release','platform'])['total_sales'].sum().reset_index()
data_grouped
# Out:
#     year_of_release platform  total_sales
# 0              2014      3DS        43.76
# 1              2014       PC        13.28
# 2              2014      PS3        47.76
# 3              2014      PS4       100.00
# 4              2014      PSP         0.24
# 5              2014      PSV        11.90
# 6              2014      Wii         3.75
# 7              2014     WiiU        22.03
# 8              2014     X360        34.74
# 9              2014     XOne        54.07
# 10             2015      3DS        27.78
# 11             2015       PC         8.52
# 12             2015      PS3        16.82
# 13             2015      PS4       118.90
# 14             2015      PSP         0.12
# 15             2015      PSV         6.25
# 16             2015      Wii         1.14
# 17             2015     WiiU        16.35
# 18             2015     X360        11.96
# 19             2015     XOne        60.14
# 20             2016      3DS        15.14
# ...

# %% [markdown]
# Визуализируем

# %%
fig, ax = plt.subplots(figsize=(15, 6))
for platform in platform_slice:
    data_platform = data_grouped.query('platform == @platform')
    ax.plot(data_platform['year_of_release'],
    data_platform['total_sales'], label = platform)
ax.legend()
ax.set_title ('Распределение суммарных продаж по платформам и годам релиза')
ax.set_xlabel('Год выпуска')
ax.set_ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# По графику видно, что игры на PS4 и XOne набирают обороты. В тройку лидеров также входит 3DS.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Можно подправить подписи оси х, в виде целых 2014, 2015 ...,
#
# искать тему Ticks and ticklabels
#
# https://matplotlib.org/stable/tutorials/text/text_intro.html
#
# или
#
# https://dev-gang.ru/article/izmenenie-czastoty-tikov-v-matplotlib-k5x1kznn39/?ysclid=lcp5si8pky848462627

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#         Шум от данных за 2013 год помешает увидеть настоящих лидеров ...

# %% [markdown]
# Построим диаграммы "ящик с усами" по глобальным продажам

# %%
fig2, ax2 = plt.subplots(figsize = (18,10))
sns.boxplot(x = data_slice['platform'], y = data_slice['total_sales'])
plt.title('Диаграмма "ящик с усами" по глобальным продажам')
ax2.set_xlabel('Платформа')
ax2.set_ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# К сожалению, на этом графике видны только выбросы, и совсем не видны медиана и 75% квантиль. Для более обоснованных выводов cтоит добавить второй вид, с другим масштабом по оси y, где будет отображена только нижняя часть boxplot-ов
#
# Оба вида важны, т.к. выбросы — это наши звезды, которые приносят максимум выручки

# %%
total_sales_per_platform
# Out:
#   platform  total_sales
# 3      PS4       288.15
# 9     XOne       140.36
# 0      3DS        86.68
# 2      PS3        68.18
# 8     X360        48.22
# 7     WiiU        42.98
# 1       PC        27.05
# 5      PSV        22.40
# 6      Wii         5.07
# 4      PSP         0.36

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все надписи для графиков стоит оформлять на языке выполнения проекта

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Пофиксил

# %% [markdown]
# Можно заметить, что наиболее продаваемые игры на платформы -  PS4, XOne, 3DS. Платформы PS3, X360, WiiU являются из предшественниками. Продажи на них с большой долей вероятности не будут расти.
#
# В основном продажи игр на этих платформах не превышает 1 млн.копий, однако есть некоторые проекты, которые продаются тиражом свыше 4 млн копий

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# X360 и PS3 уже исполнилось 11 лет и они с малой вероятностью станут перспективными или сохранят продажи в 2017 году -  стоит отметить это для маркетологов

# %% [markdown]
# ### check

# %% [markdown]
# # example 1

# %% [markdown]
# #### example 3

# %% [markdown]
# ##### example 4

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# стоит выделять разделы проекта заголовками разного уровня, за уровень отвечает количество знаков #
#
#         # example 1
#
#         #### example 3
#
#         ##### example 4

# %% [markdown]
# Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.

# %%
data_slice.query('platform == "XOne"').plot(x='critic_score', y='total_sales', kind='scatter', alpha=0.5)
plt.title('Диаграмма рассеяния для XOne')
plt.xlabel('Оценка критиков')
plt.ylabel('Суммарные продажи')
plt.show()

# %%
corr_critic_total = data_slice.query('platform == "XOne"')['critic_score'].corr(
    data_slice.query('platform == "XOne"')['total_sales'])
print(f'Корреляция между оценкой критиков и общими продажами: {corr_critic_total:.1%}')
# Out:
# Корреляция между оценкой критиков и общими продажами: 42.9%

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# стоит избавиться от любых видов заглушек при расчете коэф. корреляции (нулевых, отрицательных, положительных)

# %%
data_slice.query('platform == "XOne"').plot(x='user_score', y='total_sales', kind='scatter', alpha=0.5)
plt.title('Диаграмма рассеяния для XOne')
plt.xlabel('Оценка пользователей')
plt.ylabel('Суммарные продажи')
plt.show()

# %%
corr_user_total = data_slice.query('platform == "XOne"')['user_score'].corr(
    data_slice.query('platform == "XOne"')['total_sales'])
print(f'Корреляция между оценкой пользователей и общими продажами: {corr_user_total:.1%}')
# Out:
# Корреляция между оценкой пользователей и общими продажами: -7.0%

# %% [markdown]
# Глядя графики рассеивания и рассчитанные коэффициенты корелляции можно сделать вывод о том, что оценка критиков и оценки пользователей не выражены прямой пропорциональной зависимостью. Однако, можно заметить нелинейный тренд на диаграмме рассеяния: чем выше оценка критиков тем больше суммарные продажи.

# %% [markdown]
# Для того, чтобы убедиться в этом, можем взять еще несколько платформ и проверить это:

# %%
platform_slice_upd = ['PS4', '3DS']
for platform in platform_slice_upd:
    print (f'Для платформы: {platform}')
    corr_user_total = data_slice.query('platform in @platform')['user_score'].corr(
        data_slice.query('platform in @platform')['total_sales'])
    print(f'Корреляция между оценкой пользователей и общими продажами: {corr_user_total:.1%}')
    corr_critic_total = data_slice.query('platform in @platform')['critic_score'].corr(
        data_slice.query('platform in @platform')['total_sales'])
    print(f'Корреляция между оценкой критиков и общими продажами: {corr_critic_total:.1%}')
    print()
# Out:
# Для платформы: PS4
# Корреляция между оценкой пользователей и общими продажами: -4.0%
# Корреляция между оценкой критиков и общими продажами: 40.3%
#
# Для платформы: 3DS
# Корреляция между оценкой пользователей и общими продажами: 21.5%
# Корреляция между оценкой критиков и общими продажами: 31.4%

# %%
data_slice.query('platform == "3DS"').plot(x='critic_score', y='total_sales', kind='scatter', alpha=0.5)
plt.title('Диаграмма рассеяния для 3DS')
plt.xlabel('Оценка критиков')
plt.ylabel('Суммарные продажи')
plt.show()

# %%
data_slice.query('platform == "3DS"').plot(x='user_score', y='total_sales', kind='scatter', alpha=0.5)
plt.title('Диаграмма рассеяния для 3DS')
plt.xlabel('Оценка пользователей')
plt.ylabel('Суммарные продажи')
plt.show()

# %%
data_slice.query('platform == "PS4"').plot(x='critic_score', y='total_sales', kind='scatter', alpha=0.5)
plt.title('Диаграмма рассеяния для PS4')
plt.xlabel('Оценка критиков')
plt.ylabel('Суммарные продажи')
plt.show()

# %%
data_slice.query('platform == "PS4"').plot(x='user_score', y='total_sales', kind='scatter', alpha=0.5)
plt.title('Диаграмма рассеяния для PS4')
plt.xlabel('Оценка пользователей')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# В результате теста наша гипотеза подтвердилась.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />     Стоит добавить парочку диаграмм рассеяния, коэф. корреляции отображает лишь возможное наличие линейной связи и пересмотреть вывод после исправления расчетов

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал. Вывод тоже изменился

# %% [markdown]
# Посмотрим распределение суммарных продаж по жанрам игр:

# %%
data_slice_genre = data_slice.groupby('genre')['total_sales'].sum().sort_values(ascending = False).plot(
    kind = 'bar', figsize = (10,5))
plt.title ('Суммарные продажи игр по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# Построим диаграмму размаха, чтобы проверить стабильность жанров

# %%
fig3, ax3 = plt.subplots(figsize = (18,10))
sns.boxplot(x = data_slice['genre'], y = data_slice['total_sales'])
plt.title('Диаграмма "ящик с усами" по глобальным продажам')
ax2.set_xlabel('Жанр')
ax2.set_ylabel('Суммарные продажи')
plt.show()

# %%
fig3, ax3 = plt.subplots(figsize = (18,10))
sns.boxplot(x = data_slice['genre'], y = data_slice['total_sales'])
plt.title('Диаграмма "ящик с усами" по глобальным продажам')
ax3.set_xlabel('Жанр')
ax3.set_ylabel('Суммарные продажи')
ax3.set_ylim(0, 4)
plt.show()

# %% [markdown]
# Исходя из графиков размаха и гистограммы можно сделать следующие выводы:
#
# 1. Наиболее популярны жанры Action, Shooter, Sports.
# 2. Медианные продажи по жанру Shooter выше чем у Sports и Action.
# 3. Наиболее стабильно себя показывает жанр Shooter
# 4. Наименее стабильно себя ведет жанр Action.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %% [markdown]
#  <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Круговая диаграмма малоинформативна для кол-ва категорий более 5-ти, невозможно за 5 сек. сравнить и решить какой вид жанра является отстающим, а самое главное тяжело сравнивать разные сектора

# %% [markdown]
# Выводы:
#
#     - Средний срок жизни платформы - 6 лет
#     - Наиболее перспективные платформы - PS4, XOne, 3DS
#     - Оценки критиков влияет на продажи, а оценка пользователей практически не влияют них.
#     - Наиболее популярны жанры Action, Shooter, Sports. Наименее популярны - Strategy, Puzzle, Simulation.
#     - Наиболее стабильный жанр - Shooter.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделал.

# %% [markdown]
# ## check

# %% [markdown]
# # Портрет пользователя каждого региона

# %% [markdown]
# Для каждого региона определим топ-5 платформ (данные будем брать все также за последние 8 лет):

# %%
fig4, axs4 = plt.subplots(1, 3, figsize=(15, 5))

regions = [('na_sales', 'Топ-5 платформ в Северной Америке'), 
           ('eu_sales', 'Топ-5 платформ в Европе'), 
           ('jp_sales', 'Топ-5 платформ в Японии')]

for i, (region, title) in enumerate(regions):
    top_platforms = data_slice.groupby('platform')[region].sum().sort_values(ascending=False)
    top_5_platforms = top_platforms.head(5)
    top_5_platforms['Other'] = top_platforms[5:].sum()

    axs4[i].pie(top_5_platforms, labels=top_5_platforms.index, autopct='%1.1f%%', wedgeprops={'edgecolor': 'white'})
    axs4[i].set_title(title, fontsize=14)

plt.suptitle('Обзор рынка платформ', fontsize=16)
plt.show()

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил.

# %% [markdown]
# Исходя из круговых диаграмм можно сделать вывод о том, что в Европе и Северной Америке предпочитают играть на стационарных консолях. В то время как в Японии - люди предпочитают портативные консоли.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, значительное влияние на портрет оказывает период с 2009 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, молодец

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# Для каждого региона определим топ-5 жанров (данные будем брать все также за последние 8 лет):

# %%
fig5, axs5 = plt.subplots(1, 3, figsize=(15, 5))

regions = [('na_sales', 'Топ-5 жанров в Северной Америке'), 
           ('eu_sales', 'Топ-5 жанров в Европе'), 
           ('jp_sales', 'Топ-5 жанров в Японии')]

for i, (region, title) in enumerate(regions):
    top_genres = data_slice.groupby('genre')[region].sum().sort_values(ascending=False)
    top_5_genres = top_genres.head(5)
    top_5_genres['Other'] = top_genres[5:].sum()

    axs5[i].pie(top_5_genres, labels=top_5_genres.index, autopct='%1.1f%%', wedgeprops={'edgecolor': 'white'})
    axs5[i].set_title(title, fontsize=14)

plt.suptitle('Обзор рынка жанров', fontsize=16)
plt.show()

# %% [markdown]
# Исходя из круговых диаграмм можно сделать вывод о том, что в Европе и Северной Америке предпочтения среди жанров игр не отличаются. Для азиатского региона наиболее предпочтительным жанром является РПГ. Это может быть связано с тем, что в Японии существует культ "вымышленного мира". Этим объясняется также пониженный интерес к шутерам и файтингам.

# %% [markdown]
# Теперь проверим, влияет ли рейтинг ESRB на продажи в отдельном регионе

# %%
fig, axs6 = plt.subplots(1, 3, figsize=(15, 5))

regions = [('na_sales', 'Топ-5 рейтингов в Северной Америке'), 
           ('eu_sales', 'Топ-5 рейтингов в Европе'), 
           ('jp_sales', 'Топ-5 рейтингов в Японии')]

for i, (region, title) in enumerate(regions):
    top_ratings = data_slice.groupby('rating')[region].sum().sort_values(ascending=False)
    top_5_ratings = top_ratings.head(5)
    top_5_ratings['Other'] = top_ratings[5:].sum()

    axs6[i].pie(top_5_ratings, labels=top_5_ratings.index, autopct='%1.1f%%', wedgeprops={'edgecolor': 'white'})
    axs6[i].set_title(title, fontsize=14)

plt.suptitle('Обзор рынка рейтингов', fontsize=16)
plt.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Широкие строки кода рекомендуется — делить на всем проекте <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Исходя из круговых диаграмм, предположу, что without rating можно внести в категорию E - Everyone (основываясь на сходстве распределений для Европы и Северной Америки). Также это объяснит незаполненность в датасете.
#
# В Европе и Северной америке преобладает жанр M -для взрослых. Это коррелирует с тем, что высокую долю занимают жанры - шутер.
#
# В Японии наиболее распространен жанр - для всех. Это коррелирует с тем, что наиболее популярный жанр - РПГ. Также отсутствие рейтинга ESRB в Японии можно объяснить тем, что раздачей рейтинга играм там занимается другая организация CERO.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Интересно в чем причина, что на рынке Японии продается так много игр без рейтинга ESRB

# %% [markdown]
# ## check

# %% [markdown]
# # Общий вывод

# %% [markdown]
# 1. Средний срок жизни платформы - 6 лет.
# 2. Наиболее перспективные платформы - PS4, XOne, 3DS.
# 3. Наиболее популярные платформы в Европе и Северной Америке - стационарные консоли.
# 4. Наиболее популярные платформы в Японии - портативные консоли.
# 5. Регионы Европа и Северная Америка очень похожи по своим предпочтениям.
# 6. Наиболее популярные жанры в Европе и Северной америке - Action, Shooter, Sports.
# 7. Наиболее устойчиво и прогнозируемо себя ведет жанр Shooter.
# 8. Наиболее популярный жанр в Японии - RPG.
# 9. В Европе и Северной Америке наиболее продаваемые игры имеют возрастной рейтинг - Для взрослых.
# 10. В Японии наиболее продаваемые игры имеют возрастной рейтинг - для всех.
# 11. Оценка критиков влияет на суммарные продажи игры.
# 12. Данные за 2016 год неполные - так как по графикам наблюдается резкое снижение продаж.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для уточнения характеристики стоит определить характерный срок от начала до завершения продаж по нескольким крупным платформам (отдельно)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# ## check

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно
#
# стоит перепроверить результаты после определения актуального периода и исправления всех комментариев, можно добавить названия самых актуальных платформ, жанров и рейтингов, какую долю они занимают на исследуемых рынках

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Исправил.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + добавить оформления во вступительную часть
#  + заполнение пропусков в колонке год выпуска
#  + изменить тип данных
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + выполнить проверку на дублирование записей
#  + самое важное — переопределить актуальный период
#  + поправить и добавить исследование зависимости по платформам конкурентам (от оценок критиков и пользователей)
#  + оценить прибыльность жанров на диаграмме размаха
#  + достроить графики в ТОП-5
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
#
# Плюс
#
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)

# %% [markdown]
# ## Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие

# функция не работает на версии библиотеки pandas = 2.0 (метод .append устарел)

def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
# Цветовая гамма не подбиралась специально под платформы, кому-что попадется, 😉      
      
    labels_c=sales.platform
    colours = {'Wii':'C60', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'lightsteelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'Fuchsia', '2600':'C15', 'PSP':'C48', 
               'XOne':'LimeGreen',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2009

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %%
# check
# круги в ряд

x_year = 2013

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.  по 2016 г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])
